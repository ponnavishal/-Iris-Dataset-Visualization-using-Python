# %%
pip install pandas seaborn matplotlib scikit-learn

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

# %%
iris = load_iris()

# %%
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
df['species'] = iris.target
df['species'] = df['species'].map({0: 'setosa', 1: 'versicolor', 2: 'virginica'})

# %%
# 📌 Step 4: Display the first few rows of the dataset
print("🔍 First 5 Rows of the Iris Dataset:")
print(df.head())
# Out:
# 🔍 First 5 Rows of the Iris Dataset:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
sns.pairplot(df, hue="species", palette="Set2")
plt.suptitle(" Pairplot: Feature Relationships by Species", y=1.02)
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(df.drop('species', axis=1).corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("🔥 Heatmap: Feature Correlation")
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128293 (\N{FIRE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Sepal length
plt.figure(figsize=(8, 6))
sns.boxplot(x='species', y='sepal length (cm)', data=df, palette="Set3")
plt.title("📦 Boxplot: Sepal Length per Species")
plt.show()
# Out:
# /tmp/ipython-input-17-1777829438.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='species', y='sepal length (cm)', data=df, palette="Set3")
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128230 (\N{PACKAGE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Petal width
plt.figure(figsize=(8, 6))
sns.boxplot(x='species', y='petal width (cm)', data=df, palette="Set2")
plt.title("📦 Boxplot: Petal Width per Species")
plt.show()
# Out:
# /tmp/ipython-input-18-1664049274.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='species', y='petal width (cm)', data=df, palette="Set2")
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128230 (\N{PACKAGE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(x='species', y='petal length (cm)', data=df, palette="Pastel1")
plt.title("🎻 Violin Plot: Petal Length Distribution by Species")
plt.show()
# Out:
# /tmp/ipython-input-19-2076929870.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='species', y='petal length (cm)', data=df, palette="Pastel1")
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 127931 (\N{VIOLIN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize=(8, 6))
for species in df['species'].unique():
    sns.histplot(df[df['species'] == species]['petal length (cm)'], label=species, kde=True)
plt.legend()
plt.title("📊 Histogram: Petal Length by Species")
plt.xlabel("Petal Length (cm)")
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
